# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pygadgetreader import *

# %%
pos = readsnap("snapshot_005", 'pos', 'dm')
# Out:
# Returning DM    Positions

# %%
slice_id = where(pos[:,1]<1000)
scatter(pos[slice_id,0], pos[slice_id,2], s=1.0)
